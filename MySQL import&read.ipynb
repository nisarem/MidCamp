# %%
import pandas as pd
import numpy as np

import pymysql                        # for getting data from a SQL database
from sqlalchemy import create_engine  # for establishing the connection and authentication

from getpass import getpass

# %%
password = getpass()
# Out:
# ········

# %%
connection_string = 'mysql+pymysql://root:'+password+'@localhost/Velib'
engine = create_engine(connection_string)

# %%
availability = pd.read_csv('availability.csv')

# %%
availability.to_sql('availability', con=engine, if_exists='replace', index=False, schema='Velib')
# Out:
# 1432

# %%
durations = pd.read_csv('durations.csv')

# %%
durations.to_sql('durations', con=engine, if_exists='replace', index=False, schema='Velib')
# Out:
# 1442

# %%
df = pd.read_csv('df.csv')

# %%
df.to_sql('logs', con=engine, if_exists='replace', index=False, schema='Velib')
# Out:
# 330180

# %%
durations = pd.read_sql_query('SELECT * FROM Velib.durations', engine)

# %%
durations
# Out:
#       duration_id  station_ID                                    nom  \
# 0               1       14106        Marc Sangnier - Porte de Vanves
# 1               2       10161  Gare de l'Est - Faubourg-Saint-Martin
# 2               3       14101       Gare Montparnasse - Edgar Quinet
# 3               4       10009                        Mairie du 10ème
# 4               5       10161  Gare de l'Est - Faubourg-Saint-Martin
# ...           ...         ...                                    ...
# 1437         1438        8202                       Londres - Europe
# 1438         1439        5106                   Cujas - Saint-Michel
# 1439         1440        8549           George V - Christophe Colomb
# 1440         1441        5106                   Cujas - Saint-Michel
# 1441         1442        5106                   Cujas - Saint-Michel
#
#                                  coordinates communes  capacity  \
# 0     48.825218683556734, 2.3107116669416428    Paris      21.0
# ...

# %%
availability = pd.read_sql_query('SELECT * FROM Velib.stations', engine)

# %%
availability
# Out:
#       station_ID                              nom  \
# 0           1001    Quai de l'Horloge - Pont Neuf
# 1           1002     Victoria - Place du Chatelet
# 2           1003             Saint-Denis - Rivoli
# 3           1006  Grande Truanderie - Saint-Denis
# 4           1007              Turbigo - Française
# ...          ...                              ...
# 1427       92004            Nanterre - Université
# 1428       92005           Gare de Nanterre Ville
# 1429       92006             Place Nelson Mandela
# 1430       92007              Pesaro - Préfecture
# 1431       92008       Hôtel de Ville de Nanterre
#
#                                  coordinates                  communes  \
# 0           48.857058739111, 2.3417982839439  Paris 01e Arrondissement
# 1           48.857992591527, 2.3469167947769  Paris 01e Arrondissement
# 2           48.859059340842, 2.3476943001151  Paris 01e Arrondissement
# 3                      48.8626302, 2.3498075  Paris 01e Arrondissement
# ...

# %%
df = pd.read_sql_query('SELECT * FROM Velib.logs', engine)

# %%
df
# Out:
#         log_id  station_ID                                        nom  status  \
# 0            1       15062                       Convention - Lourmel       1
# 1            2       16139                Suresnes - Muette à Neuilly       1
# 2            3       18019                     Square Raymond Souplex       1
# 3            4       16138                   Saint-Cloud - Hippodrome       1
# 4            5       18019                     Square Raymond Souplex       1
# ...        ...         ...                                        ...     ...
# 330175  330176       17127  Porte de Clichy - Place des Nations Unies       1
# 330176  330177       17127  Porte de Clichy - Place des Nations Unies       1
# 330177  330178       17127  Porte de Clichy - Place des Nations Unies       1
# 330178  330179       13023                 Bobillot - Moulin des Prés       1
# 330179  330180       13023                 Bobillot - Moulin des Prés       1
#
# ...
